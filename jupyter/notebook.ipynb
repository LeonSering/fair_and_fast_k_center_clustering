# %%
from ff_k_center import FFKCenter

# %%
model = FFKCenter(4,1,[(1,2)])

# %%
model.fit([[1,2],[0,0],[6,7],[0,-1],[-2,-3],[0,-1.2],[1,3],[6,1]],[0,0,0,1,1,0,0,1])
# Out:
# **** Algorithm done (total time: 331.197µs): Privacy-preserving representative k-center computed.

# %%
model.plot2d()

# %%
model.plot2d(x_dim=1,y_dim=0)

# %%
model.cluster_labels
# Out:
# [0, 0, 1, 2, 2, 2, 0, 3]

# %%
model.centers
# Out:
# [0, 2, 4, 7]

# %%
model.assignment
# Out:
# [0, 0, 2, 4, 4, 4, 0, 7]

# %%
model.rep_intervals

# %%
model.privacy_bound

# %%
model.save_to_file("output/test.clustering")
